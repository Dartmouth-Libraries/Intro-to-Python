# %%
# Generally useful libs
from pathlib import Path
import pandas as pd
import numpy as np
import pickle
import math
import os
import re

# For visualisation
# %matplotlib inline     
# Assumes Jupyter notebook
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

# For word embeddings
#from gensim.models.word2vec import Word2Vec

# For parquet files
import pyarrow

# For dimensionality reduction
import umap

# For automating the 'knee method'
from kneed import KneeLocator

# For hierarchical clustering
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster, centroid
from tabulate import tabulate

# For validation and visualisation
from sklearn.metrics import confusion_matrix, classification_report, silhouette_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

#from ctfidf import CTFIDFVectorizer

from wordcloud import WordCloud

# %%
textdir = Path("~/shared/RR-workshop-data/text_datasets").expanduser()
textdf = pd.read_csv("nyt_df_2023-10.csv", encoding = 'utf-8')
textdf.head()
# Out:
#    Unnamed: 0                                           abstract  \
# 0           0  The new chairman of the Senate Foreign Relatio...
# 1           1  The Senate overwhelmingly passed a bill to fun...
# 2           2  In much of Europe, the election in Slovakia wa...
# 3           3  Gideon Cody, who orchestrated a widely critici...
# 4           4  The assistant general manager of the Calgary F...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/09/30/us/politics...
# 1  https://www.nytimes.com/interactive/2023/09/30...
# 2  https://www.nytimes.com/2023/09/30/world/europ...
# 3  https://www.nytimes.com/2023/09/30/us/marion-k...
# 4  https://www.nytimes.com/2023/09/30/sports/chri...
#
#                                              snippet  \
# 0  The new chairman of the Senate Foreign Relatio...
# 1  The Senate overwhelmingly passed a bill to fun...
# 2  In much of Europe, the election in Slovakia wa...
# 3  Gideon Cody, who orchestrated a widely critici...
# 4  The assistant general manager of the Calgary F...
#
#                                       lead_paragraph              source  \
# 0  Senator Ben Cardin of Maryland, the new chairm...  The New York Times
# 1  The Senate overwhelmingly passed a bill to fun...  The New York Times
# 2  A Russia-friendly populist party finished firs...  The New York Times
# 3  The police chief of Marion, Kansas, was suspen...  The New York Times
# 4  Chris Snow, the assistant general manager of t...  The New York Times
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             keywords  \
# 0  [{'name': 'glocations', 'value': 'Egypt', 'ran...
# 1  [{'name': 'subject', 'value': 'Shutdowns (Inst...
# 2  [{'name': 'glocations', 'value': 'Slovakia', '...
# 3  [{'name': 'subject', 'value': 'Newspapers', 'r...
# 4  [{'name': 'persons', 'value': 'Snow, Chris', '...
#
#                    pub_date document_type  ... headline.content_kicker  \
# 0  2023-10-01T00:06:00+0000       article  ...                     NaN
# 1  2023-10-01T00:06:25+0000    multimedia  ...                     NaN
# 2  2023-10-01T00:18:47+0000       article  ...                     NaN
# 3  2023-10-01T00:47:45+0000       article  ...                     NaN
# 4  2023-10-01T01:38:51+0000       article  ...                     NaN
#
#                              headline.print_headline headline.name  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3  Police Chief Who Ordered Newspaper Raid Is Sus...           NaN
# 4  Chris Snow, 42, Hockey Executive Who ‘Never St...           NaN
#
#   headline.seo headline.sub  \
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
#                                      byline.original  \
# 0                                By Karoun Demirjian
# 1  By Lazaro Gamio, Alicia Parlapiano, Jasmine C....
# 2                                  By Andrew Higgins
# 3                               By Orlando Mayorquin
# 4                                       By Sopan Deb
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Karoun', 'middlename': None, '...                 NaN
# 1  [{'firstname': 'Lazaro', 'middlename': None, '...                 NaN
# 2  [{'firstname': 'Andrew', 'middlename': None, '...                 NaN
# 3  [{'firstname': 'Orlando', 'middlename': None, ...                 NaN
# 4  [{'firstname': 'Sopan', 'middlename': None, 'l...                 NaN
#
#   print_section  print_page
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3             A        21.0
# 4             B        10.0
#
# [5 rows x 29 columns]

# %%
textdf.columns
# Out:
# Index(['Unnamed: 0', 'abstract', 'web_url', 'snippet', 'lead_paragraph',
#        'source', 'multimedia', 'keywords', 'pub_date', 'document_type',
#        'news_desk', 'section_name', 'subsection_name', 'type_of_material',
#        '_id', 'word_count', 'uri', 'headline.main', 'headline.kicker',
#        'headline.content_kicker', 'headline.print_headline', 'headline.name',
#        'headline.seo', 'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization', 'print_section', 'print_page'],
#       dtype='object')

# %%
textdf_sub = textdf.loc[:, ['headline.main', 'pub_date', 'byline.person', 'word_count', 'keywords', 'document_type', 'news_desk', 'section_name', 'subsection_name', 'abstract', 'lead_paragraph']]
textdf_sub['key_text'] = textdf[['abstract', 'lead_paragraph', 'headline.main']].apply(lambda row: '\n'.join(row.values.astype(str)), axis = 1)
textdf_sub.head()
# Out:
#                                        headline.main  \
# 0  Senate Democrat Threatens to Block More of Mil...
# 1  How Each Member Voted on the Senate Stopgap Sp...
# 2  What Does a Russia-Leaning Party Win in an E.U...
# 3  Police Chief Who Ordered Raid on Kansas Newspa...
# 4  Chris Snow, Hockey Executive Who Publicly Face...
#
#                    pub_date  \
# 0  2023-10-01T00:06:00+0000
# 1  2023-10-01T00:06:25+0000
# 2  2023-10-01T00:18:47+0000
# 3  2023-10-01T00:47:45+0000
# 4  2023-10-01T01:38:51+0000
#
#                                        byline.person  word_count  \
# 0  [{'firstname': 'Karoun', 'middlename': None, '...         681
# 1  [{'firstname': 'Lazaro', 'middlename': None, '...           0
# 2  [{'firstname': 'Andrew', 'middlename': None, '...        1269
# 3  [{'firstname': 'Orlando', 'middlename': None, ...         623
# 4  [{'firstname': 'Sopan', 'middlename': None, 'l...         729
#
#                                             keywords document_type  \
# 0  [{'name': 'glocations', 'value': 'Egypt', 'ran...       article
# 1  [{'name': 'subject', 'value': 'Shutdowns (Inst...    multimedia
# 2  [{'name': 'glocations', 'value': 'Slovakia', '...       article
# 3  [{'name': 'subject', 'value': 'Newspapers', 'r...       article
# 4  [{'name': 'persons', 'value': 'Snow, Chris', '...       article
#
#     news_desk section_name subsection_name  \
# 0  Washington         U.S.        Politics
# 1    Graphics         U.S.        Politics
# 2     Foreign        World          Europe
# 3     Express         U.S.             NaN
# 4      Sports       Sports             NaN
#
#                                             abstract  \
# 0  The new chairman of the Senate Foreign Relatio...
# 1  The Senate overwhelmingly passed a bill to fun...
# 2  In much of Europe, the election in Slovakia wa...
# 3  Gideon Cody, who orchestrated a widely critici...
# 4  The assistant general manager of the Calgary F...
#
#                                       lead_paragraph  \
# 0  Senator Ben Cardin of Maryland, the new chairm...
# 1  The Senate overwhelmingly passed a bill to fun...
# 2  A Russia-friendly populist party finished firs...
# 3  The police chief of Marion, Kansas, was suspen...
# 4  Chris Snow, the assistant general manager of t...
#
#                                             key_text
# 0  The new chairman of the Senate Foreign Relatio...
# 1  The Senate overwhelmingly passed a bill to fun...
# 2  In much of Europe, the election in Slovakia wa...
# 3  Gideon Cody, who orchestrated a widely critici...
# 4  The assistant general manager of the Calgary F...

# %% [markdown]
# # Lemmatization (be consistent and use same process as in previous nbs!!)

# %%
# lemmatization (optional step)
""" import spacy
import re
nlp = spacy.load("en_core_web_sm")

def lemmatizeAbstracts(x):
    doc = nlp(x)
    new_text = []
    for token in doc:
        new_text.append(token.lemma_)
    text_string = " ".join(new_text)
    # getting rid of non-word characters
    text_string = re.sub(r"[^\w\s]+", "", text_string)
    text_string = re.sub(r"\s{2,}", " ", text_string)
    return text_string

textdf_sub["keytext_lemma"] = textdf_sub["key_text"].apply(lemmatizeAbstracts)
textdf_sub.loc[:2, ['key_text', 'keytext_lemma']] """
# Out:
# ' import spacy\nimport re\nnlp = spacy.load("en_core_web_sm")\n\ndef lemmatizeAbstracts(x):\n    doc = nlp(x)\n    new_text = []\n    for token in doc:\n        new_text.append(token.lemma_)\n    text_string = " ".join(new_text)\n    # getting rid of non-word characters\n    text_string = re.sub(r"[^\\w\\s]+", "", text_string)\n    text_string = re.sub(r"\\s{2,}", " ", text_string)\n    return text_string\n\ntextdf_sub["keytext_lemma"] = textdf_sub["key_text"].apply(lemmatizeAbstracts)\ntextdf_sub.loc[:2, [\'key_text\', \'keytext_lemma\']] '

# %%
# Random seed
rs = 43

# Which embeddings to use
src_embeddings = 'doc_vec'

# %%
dmeasure = 'euclidean' # distance metric
rdims    = 4 # r-dims == Reduced dimensionality
print(f"UMAP dimensionality reduction to {rdims} dimensions with '{dmeasure}' distance measure.")
# Out:
# UMAP dimensionality reduction to 4 dimensions with 'euclidean' distance measure.

# %%
# Extract the embedding from a list-type column
# in the source data frame using this function
def x_from_df(df:pd.DataFrame, col:str='Embedding') -> pd.DataFrame:
    cols = ['E'+str(x) for x in np.arange(0,len(df[col].iloc[0]))]
    return pd.DataFrame(df[col].tolist(), columns=cols, index=df.index)

X = x_from_df(textdf_sub, col=src_embeddings)

# Create and apply a UMAP 'reducer'
reducer = umap.UMAP(
    n_neighbors=25,
    min_dist=0.01,
    n_components=rdims,
    random_state=rs)

X_embedded = reducer.fit_transform(X)

# Create a dictionary that is easily converted into a pandas df
embedded_dict = {}
for i in range(0,X_embedded.shape[1]):
    embedded_dict[f"Dim {i+1}"] = X_embedded[:,i] # D{dimension_num} (Dim 1...Dim n)

dfe = pd.DataFrame(embedded_dict, index=textdf_sub.index)
del(embedded_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\F0040RP\Documents\DartLib_RDS\intro-to-python\.venv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'doc_vec'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\F0040RP\Documents\DartLib_RDS\intro-to-python\TAW\clustering_word-embeddings.ipynb Cell 9 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     cols = ['E'+str(x) for x in np.arange(0,len(df[col].iloc[0]))]
#       <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     return pd.DataFrame(df[col].tolist(), columns=cols, index=df.index)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> X = x_from_df(textdf_sub, col=src_embeddings)
#       <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> # Create and apply a UMAP 'reducer'
#      <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> reducer = umap.UMAP(
#      <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     n_neighbors=25,
#      <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>     min_dist=0.01,
#      <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     n_components=rdims,
#      <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>     random_state=rs)
#
# c:\Users\F0040RP\Documents\DartLib_RDS\intro-to-python\TAW\clustering_word-embeddings.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> def x_from_df(df:pd.DataFrame, col:str='Embedding') -> pd.DataFrame:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     cols = ['E'+str(x) for x in np.arange(0,len(df[col].iloc[0]))]
#       <a href='vscode-notebook-cell:/c%3A/Users/F0040RP/Documents/DartLib_RDS/intro-to-python/TAW/clustering_word-embeddings.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     return pd.DataFrame(df[col].tolist(), columns=cols, index=df.index)
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\intro-to-python\.venv\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Users\F0040RP\Documents\DartLib_RDS\intro-to-python\.venv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'doc_vec'

# %%
src_embeddings
# Out:
# 'doc_vec'
